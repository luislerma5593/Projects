# %% [markdown]
# ## Forst fire prediction

# %% [markdown]
# ### 1. EDA

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Documents\_Datasets\Forest_fire_prediction\Algerian_forest_fires_dataset_UPDATE.csv", header = 1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# Data cleaning

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[110:130,:]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 110                             19     09  2012           29   57   14      0
# 111                             20     09  2012           28   84   18      0
# 112                             21     09  2012           31   55   11      0
# 113                             22     09  2012           31   50   19    0.6
# 114                             23     09  2012           32   54   11    0.5
# 115                             24     09  2012           29   65   19    0.6
# 116                             25     09  2012           26   81   21    5.8
# 117                             26     09  2012           31   54   11      0
# 118                             27     09  2012           31   66   11      0
# 119                             28     09  2012           32   47   14    0.7
# 120                             29     09  2012           26   80   16    1.8
# ...

# %% [markdown]
# It looks like records from index 0-121 are for the region **"Bejaia Region Dataset"**
#
# Records from index 124:, are from the region **"Sidi-Bel Abbes Region Dataset"**

# %%
df.loc[:122, 'Region'] = 1
df.loc[122:, 'Region'] = 2

# %%
df['Region'] = df['Region'].astype('int')

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
#Remove column where the new region starts
df = df.drop([122,123]).reset_index(drop=True)

# %%
df.loc[120:124,:]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 120  29    09  2012          26  80  16   1.8  47.4  2.9  7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9  7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
# 123  02    06  2012          30  73  13     4  55.7  2.7  7.8  0.6  2.9  0.2
# 124  03    06  2012          29  80  14     2  48.7  2.2  7.6  0.3  2.6  0.1
#
#        Classes    Region
# 120  not fire          1
# 121  not fire          1
# 122  not fire          2
# 123  not fire          2
# 124  not fire          2

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %% [markdown]
# There are some spaces at the beginning or end of the headers, let's remove them.

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# The following columns are integers:
# * Day
# * Month
# * Year
# * Temperature
# * RH
# * Ws
#
# The rest are floats. Let's change the data types.

# %%
df[['month', 'day', 'year', 'Temperature','RH', 'Ws']] = df[['month', 'day', 'year', 'Temperature','RH', 'Ws']].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int32
#  1   month        244 non-null    int32
#  2   year         244 non-null    int32
#  3   Temperature  244 non-null    int32
#  4   RH           244 non-null    int32
#  5   Ws           244 non-null    int32
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.1+ KB

# %% [markdown]
# There's an error with the following record:
# * DC value with a space
# * FWI value says 'fire
#
# The best idea would be to remove this record, it may contain more errors in the values

# %%
df.loc[164:167,:]
# Out:
#      day  month  year  Temperature  RH  Ws Rain  FFMC   DMC      DC   ISI  \
# 164   13      7  2012           39  45  13  0.6  85.2  11.3    10.4   4.2
# 165   14      7  2012           37  37  18  0.2  88.9  12.9  14.6 9  12.5
# 166   15      7  2012           34  45  17    0  90.5    18    24.1  10.9
# 167   16      7  2012           31  83  17    0  84.5  19.4    33.1   4.7
#
#       BUI      FWI  Classes  Region
# 164  10.9      4.7  fire          2
# 165  10.4  fire         NaN       2
# 166  17.7     14.1  fire          2
# 167  19.2      7.3  fire          2

# %%
df = df.drop(165).reset_index(drop=True)

# %%
df.loc[164:167,:]
# Out:
#      day  month  year  Temperature  RH  Ws Rain  FFMC   DMC    DC   ISI   BUI  \
# 164   13      7  2012           39  45  13  0.6  85.2  11.3  10.4   4.2  10.9
# 165   15      7  2012           34  45  17    0  90.5    18  24.1  10.9  17.7
# 166   16      7  2012           31  83  17    0  84.5  19.4  33.1   4.7  19.2
# 167   17      7  2012           32  81  17    0  84.6  21.1  42.3   4.7  20.9
#
#       FWI  Classes  Region
# 164   4.7  fire          2
# 165  14.1  fire          2
# 166   7.3  fire          2
# 167   7.7  fire          2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB
